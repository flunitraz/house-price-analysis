# %% [markdown]
# # DATA PREPROCESSING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.mode.chained_assignment = None  # default='warn'

# %% [markdown]
# ### Veri Setinin Upload Edilmesi

# %%
df = pd.read_csv('../data/zingat_raw.csv', low_memory=False)

# %%
df
# Out:
#        Unnamed: 0 Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi  \
# 0               0    100   110m²                   7  Kombi (Doğalgaz)
# 1               1    105   115m²                   5  Kombi (Doğalgaz)
# 2               2    150   170m²         10-20 arası             Klima
# 3               3    100   110m²                   5             Klima
# 4               4    100   120m²                   5             Klima
# ...           ...    ...     ...                 ...               ...
# 27346       27346     65    85m²                   4    Kat Kaloriferi
# 27347       27347    135   145m²                   6  Kombi (Doğalgaz)
# 27348       27348    130   141m²                   6  Kombi (Doğalgaz)
# 27349       27349     90   110m²                   4  Kombi (Doğalgaz)
# 27350       27350    150   160m²         10-20 arası  Kombi (Doğalgaz)
#
#       Bulunduğu Kat    Bina Yaşı     Mobilya Durumu Kullanım Durumu  \
# 0                 3  26-30 arası            Eşyasız             Boş
# 1                 3            0            Eşyasız             Boş
# 2                 8  11-15 arası            Eşyasız             Boş
# 3                 2            0  Sadece Beyaz Eşya             Boş
# 4                 2            3  Sadece Beyaz Eşya             Boş
# ...             ...          ...                ...             ...
# 27346             1            4  Sadece Beyaz Eşya     Mülk Sahibi
# 27347             1   6-10 arası            Eşyasız        Kiracılı
# 27348             2            0            Eşyasız             Boş
# 27349             1   6-10 arası            Eşyasız        Kiracılı
# 27350            11   6-10 arası            Eşyasız        Kiracılı
#
#       Krediye Uygun  ...  \
# 0             Hayır  ...
# 1              Evet  ...
# 2              Evet  ...
# 3              Evet  ...
# 4              Evet  ...
# ...             ...  ...
# 27346          Evet  ...
# 27347          Evet  ...
# 27348          Evet  ...
# 27349          Evet  ...
# 27350          Evet  ...
#
#       Video Home Tour\n                                                                ?  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27346                                                NaN
# 27347                                                NaN
# 27348                                                NaN
# 27349                                                NaN
# 27350                                                NaN
#
#       Unit Exchange Pet Friendly Paws Houses  Layout Parcelled    Fiyat  \
# 0               NaN                      NaN     NaN       NaN  1350000
# 1               NaN                      NaN     NaN       NaN   927000
# 2               NaN                      NaN     NaN       NaN  2300000
# 3               NaN                      NaN     NaN       NaN  2800000
# 4               NaN                      NaN     NaN       NaN  2623000
# ...             ...                      ...     ...       ...      ...
# 27346           NaN                      NaN     NaN       NaN   975000
# 27347           NaN                      NaN     NaN       NaN  1050000
# 27348           NaN                      NaN     NaN       NaN  1550000
# 27349           NaN                      NaN     NaN       NaN   935000
# 27350           NaN                      NaN     NaN       NaN  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 40 columns]

# %% [markdown]
# ### Eşik Değer Belirlenmesi

# %% [markdown]
# Eşik değer ile veri setinin kolonlarında bu belirlenen eşik değerin altında kalan dummy data'ların threshold (eşik değer) kadar olanı silinir. Örneğin threshold 0.6 için veri setindeki kolonlarda %40'a kadar veri anlamsız veya null olduğu için silinir.

# %%
threshold = 0.6
df = df[df.columns[df.isnull().mean() < threshold]]

# %%
df
# Out:
#        Unnamed: 0 Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi  \
# 0               0    100   110m²                   7  Kombi (Doğalgaz)
# 1               1    105   115m²                   5  Kombi (Doğalgaz)
# 2               2    150   170m²         10-20 arası             Klima
# 3               3    100   110m²                   5             Klima
# 4               4    100   120m²                   5             Klima
# ...           ...    ...     ...                 ...               ...
# 27346       27346     65    85m²                   4    Kat Kaloriferi
# 27347       27347    135   145m²                   6  Kombi (Doğalgaz)
# 27348       27348    130   141m²                   6  Kombi (Doğalgaz)
# 27349       27349     90   110m²                   4  Kombi (Doğalgaz)
# 27350       27350    150   160m²         10-20 arası  Kombi (Doğalgaz)
#
#       Bulunduğu Kat    Bina Yaşı     Mobilya Durumu Kullanım Durumu  \
# 0                 3  26-30 arası            Eşyasız             Boş
# 1                 3            0            Eşyasız             Boş
# 2                 8  11-15 arası            Eşyasız             Boş
# 3                 2            0  Sadece Beyaz Eşya             Boş
# 4                 2            3  Sadece Beyaz Eşya             Boş
# ...             ...          ...                ...             ...
# 27346             1            4  Sadece Beyaz Eşya     Mülk Sahibi
# 27347             1   6-10 arası            Eşyasız        Kiracılı
# 27348             2            0            Eşyasız             Boş
# 27349             1   6-10 arası            Eşyasız        Kiracılı
# 27350            11   6-10 arası            Eşyasız        Kiracılı
#
#       Krediye Uygun    Fiyat         İl              İlçe  \
# 0             Hayır  1350000   İstanbul          Bağcılar
# 1              Evet   927000   İstanbul        Beylikdüzü
# 2              Evet  2300000   İstanbul        Beylikdüzü
# 3              Evet  2800000   İstanbul        Beylikdüzü
# 4              Evet  2623000   İstanbul        Beylikdüzü
# ...             ...      ...        ...               ...
# 27346          Evet   975000  Zonguldak           Çaycuma
# 27347          Evet  1050000  Zonguldak  Zonguldak Merkez
# 27348          Evet  1550000  Zonguldak            Ereğli
# 27349          Evet   935000  Zonguldak           Çaycuma
# 27350          Evet  1680000  Zonguldak            Ereğli
#
#                       Mahalle      Oda
# 0                       Çınar   2 + 1
# 1                  Cumhuriyet   2 + 1
# 2                       Barış   3 + 1
# 3                    Dereağzı   2 + 1
# 4                    Dereağzı   2 + 1
# ...                       ...      ...
# 27346  Filyos Bld. (Hisarönü)   1 + 1
# 27347                 İncivez   3 + 1
# 27348              Sarıkokmaz   3 + 1
# 27349                     Çay   2 + 1
# 27350                 Murtaza   3 + 1
#
# [27351 rows x 15 columns]

# %% [markdown]
#   >*40 kolondan 15 kolona düştü*

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Net m²', 'Brüt m²', 'Binadaki Kat Sayısı', 'Isıtma Tipi',
#        'Bulunduğu Kat', 'Bina Yaşı', 'Mobilya Durumu', 'Kullanım Durumu',
#        'Krediye Uygun', 'Fiyat', 'İl', 'İlçe', 'Mahalle', 'Oda'],
#       dtype='object')

# %% [markdown]
# ###### Silinmemiş işe yaramayan 'Unnamed: 0' kolonu da silinir.

# %%
df.drop(['Unnamed: 0'], axis=1, inplace = True)

# %%
df.head()
# Out:
#   Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi Bulunduğu Kat  \
# 0    100   110m²                   7  Kombi (Doğalgaz)             3
# 1    105   115m²                   5  Kombi (Doğalgaz)             3
# 2    150   170m²         10-20 arası             Klima             8
# 3    100   110m²                   5             Klima             2
# 4    100   120m²                   5             Klima             2
#
#      Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0  26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1            0            Eşyasız             Boş          Evet   927000
# 2  11-15 arası            Eşyasız             Boş          Evet  2300000
# 3            0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4            3  Sadece Beyaz Eşya             Boş          Evet  2623000
#
#          İl        İlçe     Mahalle      Oda
# 0  İstanbul    Bağcılar       Çınar   2 + 1
# 1  İstanbul  Beylikdüzü  Cumhuriyet   2 + 1
# 2  İstanbul  Beylikdüzü       Barış   3 + 1
# 3  İstanbul  Beylikdüzü    Dereağzı   2 + 1
# 4  İstanbul  Beylikdüzü    Dereağzı   2 + 1

# %% [markdown]
# ### Satırlardaki verilerin düzenlenmesi

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi Bulunduğu Kat  \
# 0        100   110m²                   7  Kombi (Doğalgaz)             3
# 1        105   115m²                   5  Kombi (Doğalgaz)             3
# 2        150   170m²         10-20 arası             Klima             8
# 3        100   110m²                   5             Klima             2
# 4        100   120m²                   5             Klima             2
# ...      ...     ...                 ...               ...           ...
# 27346     65    85m²                   4    Kat Kaloriferi             1
# 27347    135   145m²                   6  Kombi (Doğalgaz)             1
# 27348    130   141m²                   6  Kombi (Doğalgaz)             2
# 27349     90   110m²                   4  Kombi (Doğalgaz)             1
# 27350    150   160m²         10-20 arası  Kombi (Doğalgaz)            11
#
#          Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0      26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1                0            Eşyasız             Boş          Evet   927000
# 2      11-15 arası            Eşyasız             Boş          Evet  2300000
# 3                0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4                3  Sadece Beyaz Eşya             Boş          Evet  2623000
# ...            ...                ...             ...           ...      ...
# 27346            4  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000
# 27347   6-10 arası            Eşyasız        Kiracılı          Evet  1050000
# 27348            0            Eşyasız             Boş          Evet  1550000
# 27349   6-10 arası            Eşyasız        Kiracılı          Evet   935000
# 27350   6-10 arası            Eşyasız        Kiracılı          Evet  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Brüt m²** kolonunu altındaki verilerin sonundaki (suffix) m² karakterlerinin kaldırılır.

# %%
df['Brüt m²'] = df['Brüt m²'].replace('m²', '', regex=True)

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi Bulunduğu Kat  \
# 0        100     110                   7  Kombi (Doğalgaz)             3
# 1        105     115                   5  Kombi (Doğalgaz)             3
# 2        150     170         10-20 arası             Klima             8
# 3        100     110                   5             Klima             2
# 4        100     120                   5             Klima             2
# ...      ...     ...                 ...               ...           ...
# 27346     65      85                   4    Kat Kaloriferi             1
# 27347    135     145                   6  Kombi (Doğalgaz)             1
# 27348    130     141                   6  Kombi (Doğalgaz)             2
# 27349     90     110                   4  Kombi (Doğalgaz)             1
# 27350    150     160         10-20 arası  Kombi (Doğalgaz)            11
#
#          Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0      26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1                0            Eşyasız             Boş          Evet   927000
# 2      11-15 arası            Eşyasız             Boş          Evet  2300000
# 3                0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4                3  Sadece Beyaz Eşya             Boş          Evet  2623000
# ...            ...                ...             ...           ...      ...
# 27346            4  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000
# 27347   6-10 arası            Eşyasız        Kiracılı          Evet  1050000
# 27348            0            Eşyasız             Boş          Evet  1550000
# 27349   6-10 arası            Eşyasız        Kiracılı          Evet   935000
# 27350   6-10 arası            Eşyasız        Kiracılı          Evet  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Binadaki Kat Sayısı** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Binadaki Kat Sayısı"].unique()
# Out:
# array(['7', '5', '10-20 arası', '6', nan, '3', '4', '9', '20 ve üzeri',
#        '10', '8', '2', 'Between 10-20', '1', '20+'], dtype=object)

# %%
df.loc[df["Binadaki Kat Sayısı"] == "10-20 arası" , "Binadaki Kat Sayısı"] = 15
df.loc[df["Binadaki Kat Sayısı"] == "20 ve üzeri" , "Binadaki Kat Sayısı"] = 20

df.loc[df["Binadaki Kat Sayısı"] == "Between 10-20" , "Binadaki Kat Sayısı"] = 15
df.loc[df["Binadaki Kat Sayısı"] == "20+" , "Binadaki Kat Sayısı"] = 20

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı       Isıtma Tipi Bulunduğu Kat  \
# 0        100     110                   7  Kombi (Doğalgaz)             3
# 1        105     115                   5  Kombi (Doğalgaz)             3
# 2        150     170                  15             Klima             8
# 3        100     110                   5             Klima             2
# 4        100     120                   5             Klima             2
# ...      ...     ...                 ...               ...           ...
# 27346     65      85                   4    Kat Kaloriferi             1
# 27347    135     145                   6  Kombi (Doğalgaz)             1
# 27348    130     141                   6  Kombi (Doğalgaz)             2
# 27349     90     110                   4  Kombi (Doğalgaz)             1
# 27350    150     160                  15  Kombi (Doğalgaz)            11
#
#          Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0      26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1                0            Eşyasız             Boş          Evet   927000
# 2      11-15 arası            Eşyasız             Boş          Evet  2300000
# 3                0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4                3  Sadece Beyaz Eşya             Boş          Evet  2623000
# ...            ...                ...             ...           ...      ...
# 27346            4  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000
# 27347   6-10 arası            Eşyasız        Kiracılı          Evet  1050000
# 27348            0            Eşyasız             Boş          Evet  1550000
# 27349   6-10 arası            Eşyasız        Kiracılı          Evet   935000
# 27350   6-10 arası            Eşyasız        Kiracılı          Evet  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Isıtma Tipi** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Isıtma Tipi"].unique()
# Out:
# array(['Kombi (Doğalgaz)', 'Klima', nan, 'Yerden Isıtma',
#        'Kalorifer (Doğalgaz)', 'Merkezi Sistem',
#        'Merkezi Sistem (Isı Payı Ölçer)', 'Soba (Doğalgaz)',
#        'Combi Boiler (Natural Gas)', 'Central System (Heat Share Meter)',
#        'Central System', 'Soba (Kömür)', 'Fancoil', 'Jeotermal', 'Yok',
#        'Kat Kaloriferi', 'Kombi (Elektrikli)', 'Kalorifer (Akaryakıt)',
#        'Air Conditioner', 'Floor Heating', 'Kalorifer (Kömür)',
#        'Güneş Enerjisi', 'None', 'Combi Boiler (Electric)',
#        'Independent Boiler', 'Central Heating (Natural Gas)',
#        'Stove (Natural Gas)', 'Solar Power', 'Central Heating (Coal)',
#        'Stove (Coal)'], dtype=object)

# %%
df.loc[df["Isıtma Tipi"] == "-" , "Isıtma Tipi"] = 0
df.loc[df["Isıtma Tipi"] == "Yok" , "Isıtma Tipi"] = 0

df.loc[df["Isıtma Tipi"] == "Soba (Doğalgaz)" , "Isıtma Tipi"] = 1
df.loc[df["Isıtma Tipi"] == "Soba (Kömür)" , "Isıtma Tipi"] = 1

df.loc[df["Isıtma Tipi"] == "Merkezi Sistem" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kat Kaloriferi" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Merkezi Sistem (Isı Payı Ölçer)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kombi (Doğalgaz)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kalorifer (Doğalgaz)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kombi (Elektrikli)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kalorifer (Akaryakıt)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Kalorifer (Kömür)" , "Isıtma Tipi"] = 2

df.loc[df["Isıtma Tipi"] == "Yerden Isıtma" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Güneş Enerjisi" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Jeotermal" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Klima" , "Isıtma Tipi"] = 3


df.loc[df["Isıtma Tipi"] == "None" , "Isıtma Tipi"] = 0

df.loc[df["Isıtma Tipi"] == "Stove (Natural Gas)" , "Isıtma Tipi"] = 1
df.loc[df["Isıtma Tipi"] == "Stove (Coal)" , "Isıtma Tipi"] = 1

df.loc[df["Isıtma Tipi"] == "Central System" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Central Heating (Natural Gas)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Central System (Heat Share Meter)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Fancoil" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Independent Boiler" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Combi Boiler (Natural Gas)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Combi Boiler (Electric)" , "Isıtma Tipi"] = 2
df.loc[df["Isıtma Tipi"] == "Central Heating (Coal)" , "Isıtma Tipi"] = 2

df.loc[df["Isıtma Tipi"] == "Floor Heating" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Solar Power" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Geothermal" , "Isıtma Tipi"] = 3
df.loc[df["Isıtma Tipi"] == "Air Conditioner" , "Isıtma Tipi"] = 3

df["Isıtma Tipi"] = df["Isıtma Tipi"].fillna("0")

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat  \
# 0        100     110                   7           2             3
# 1        105     115                   5           2             3
# 2        150     170                  15           3             8
# 3        100     110                   5           3             2
# 4        100     120                   5           3             2
# ...      ...     ...                 ...         ...           ...
# 27346     65      85                   4           2             1
# 27347    135     145                   6           2             1
# 27348    130     141                   6           2             2
# 27349     90     110                   4           2             1
# 27350    150     160                  15           2            11
#
#          Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0      26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1                0            Eşyasız             Boş          Evet   927000
# 2      11-15 arası            Eşyasız             Boş          Evet  2300000
# 3                0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4                3  Sadece Beyaz Eşya             Boş          Evet  2623000
# ...            ...                ...             ...           ...      ...
# 27346            4  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000
# 27347   6-10 arası            Eşyasız        Kiracılı          Evet  1050000
# 27348            0            Eşyasız             Boş          Evet  1550000
# 27349   6-10 arası            Eşyasız        Kiracılı          Evet   935000
# 27350   6-10 arası            Eşyasız        Kiracılı          Evet  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Bulunduğu Kat** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Bulunduğu Kat"].unique()
# Out:
# array(['3', '8', '2', nan, '5', 'Yüksek Giriş', 'Bahçe katı', '1',
#        'Çatı Katı', '16', 'Kot 1', '4', '15', '14', '7', '6',
#        'Giriş Katı', 'Bodrum Kat', 'En Üst Kat', '13', '9', '10', '11',
#        'Zemin Kat', '12', 'Kot 3', '20 ve üzeri', '18', 'Kot 2',
#        'Teras Kat', 'Müstakil', 'Kot 4', '17', 'Elevation 1',
#        'Raised First Floor', 'Komple', '19', 'First Floor',
#        'Garden Floor', 'Top Floor'], dtype=object)

# %% [markdown]
# *Bulunduğu Kat kolonunun altındaki En Üst Kat değerine sahip verileri getirir*

# %%
df[df["Bulunduğu Kat"] == 'Kot 1']
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat  \
# 30        92     105                   4           2         Kot 1
# 98       102     117                   4           2         Kot 1
# 108       70      85                   4           2         Kot 1
# 211       70      80                   4           2         Kot 1
# 676       90      95                   1           2         Kot 1
# ...      ...     ...                 ...         ...           ...
# 27005    160     170                   5           0         Kot 1
# 27011    150     160                 NaN           0         Kot 1
# 27015    150     160                   7           0         Kot 1
# 27216    300     350                   3           2         Kot 1
# 27252    145     160                   6           2         Kot 1
#
#          Bina Yaşı Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 30               4        Eşyasız             Boş          Evet  1475000
# 98               0        Eşyasız             Boş          Evet  1550000
# 108              0            NaN             Boş          Evet  1550000
# 211    21-25 arası        Eşyasız        Kiracılı          Evet  1310000
# 676    26-30 arası        Eşyasız        Kiracılı         Hayır   660000
# ...            ...            ...             ...           ...      ...
# 27005          NaN            NaN             NaN         Hayır  1250000
# 27011            4            NaN             NaN         Hayır  1200000
# 27015            4            NaN             NaN         Hayır  1150000
# 27216  21-25 arası        Eşyasız     Mülk Sahibi          Evet  3500000
# 27252  11-15 arası        Eşyasız             NaN          Evet  1100000
#
#               İl           İlçe       Mahalle      Oda
# 30      İstanbul     Beylikdüzü       Yakuplu   2 + 1
# 98      İstanbul     Beylikdüzü       Yakuplu   2 + 1
# 108     İstanbul     Sancaktepe     Osmangazi   2 + 1
# 211     İstanbul        Üsküdar  Zeynep Kamil   2 + 1
# 676     İstanbul   Büyükçekmece      19 Mayıs   2 + 1
# ...          ...            ...           ...      ...
# 27005     Yozgat  Yozgat Merkez    Bahçeşehir   4 + 1
# 27011     Yozgat  Yozgat Merkez   Bilal Şahin   4 + 1
# 27015     Yozgat  Yozgat Merkez     Eskipazar   4 + 1
# 27216  Zonguldak         Devrek     Karşıyaka   3 + 1
# 27252  Zonguldak         Ereğli        Bağlık   3 + 1
#
# [121 rows x 14 columns]

# %% [markdown]
# > *Bu veriler sayesinde Kot 1'de bulunan dairelerin ilanlarına ulaştım ve Kot 1'de bulunan dairelerin ilanlarında geçen dairelerin gerçekte kot 1'de olmadığını farkettim. Bu yüzden Kot 1 değerine sahip sütunları None olarak adlandırdım. Böylelikle Null değerler ile birlikte bu işe yaramayan satırlar da silinmiş oldu.
# Yalan ve az veri barındıran bazı diğer 'Bulunduğu Kat' değerleri:*
#     >* Kot 1
#     >* Kot 2
#     >* Kot 3
#     >* Kot 4
#     >* Müstakil
#     >* Elevation 1
#     >* Raised First Floor
#     >* Komple
#     >* First Floor
#     >* Garden Floor
#     >* Top Floor

# %%
df.loc[df["Bulunduğu Kat"]== "Yüksek Giriş", "Bulunduğu Kat"] = 1

df.loc[df["Bulunduğu Kat"]== "Bodrum Kat", "Bulunduğu Kat"] = -1

df.loc[df["Bulunduğu Kat"]== "En Üst Kat", "Bulunduğu Kat"] = df["Binadaki Kat Sayısı"]
df.loc[df["Bulunduğu Kat"]== "Teras Kat", "Bulunduğu Kat"] = df["Binadaki Kat Sayısı"]
df.loc[df["Bulunduğu Kat"]== "Çatı Katı", "Bulunduğu Kat"] = df["Binadaki Kat Sayısı"]

df.loc[df["Bulunduğu Kat"]== "Zemin Kat", "Bulunduğu Kat"] = 0
df.loc[df["Bulunduğu Kat"]== "Bahçe katı", "Bulunduğu Kat"] = 0
df.loc[df["Bulunduğu Kat"]== "Giriş Katı", "Bulunduğu Kat"] = 0

df.loc[df["Bulunduğu Kat"]== "20 ve üzeri", "Bulunduğu Kat"] = 20

df.loc[df["Bulunduğu Kat"]== "Kot 1", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Kot 2", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Kot 3", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Kot 4", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Müstakil", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Elevation 1", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Raised First Floor", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Komple", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "First Floor", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Garden Floor", "Bulunduğu Kat"] = None
df.loc[df["Bulunduğu Kat"]== "Top Floor", "Bulunduğu Kat"] = None

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat  \
# 0        100     110                   7           2             3
# 1        105     115                   5           2             3
# 2        150     170                  15           3             8
# 3        100     110                   5           3             2
# 4        100     120                   5           3             2
# ...      ...     ...                 ...         ...           ...
# 27346     65      85                   4           2             1
# 27347    135     145                   6           2             1
# 27348    130     141                   6           2             2
# 27349     90     110                   4           2             1
# 27350    150     160                  15           2            11
#
#          Bina Yaşı     Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat  \
# 0      26-30 arası            Eşyasız             Boş         Hayır  1350000
# 1                0            Eşyasız             Boş          Evet   927000
# 2      11-15 arası            Eşyasız             Boş          Evet  2300000
# 3                0  Sadece Beyaz Eşya             Boş          Evet  2800000
# 4                3  Sadece Beyaz Eşya             Boş          Evet  2623000
# ...            ...                ...             ...           ...      ...
# 27346            4  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000
# 27347   6-10 arası            Eşyasız        Kiracılı          Evet  1050000
# 27348            0            Eşyasız             Boş          Evet  1550000
# 27349   6-10 arası            Eşyasız        Kiracılı          Evet   935000
# 27350   6-10 arası            Eşyasız        Kiracılı          Evet  1680000
#
#               İl              İlçe                 Mahalle      Oda
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Bina Yaşı** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Bina Yaşı"].unique()
# Out:
# array(['26-30 arası', '0', '11-15 arası', '3', '5', nan, '4',
#        '6-10 arası', '1', '16-20 arası', '36-40 arası', '2',
#        '21-25 arası', '31-35 arası', '40 ve üzeri', 'Between 6-10',
#        'Between 26-30', 'Between 16-20', 'Between 11-15', 'Between 21-25',
#        'Between 36-40', '40+', 'Between 31-35'], dtype=object)

# %%
df.loc[df["Bina Yaşı"] == "6-10 arası" , "Bina Yaşı"] = 8
df.loc[df["Bina Yaşı"] == "11-15 arası" , "Bina Yaşı"] = 13
df.loc[df["Bina Yaşı"] == "16-20 arası" , "Bina Yaşı"] = 18
df.loc[df["Bina Yaşı"] == "21-25 arası" , "Bina Yaşı"] = 23
df.loc[df["Bina Yaşı"] == "26-30 arası" , "Bina Yaşı"] = 28
df.loc[df["Bina Yaşı"] == "31-35 arası" , "Bina Yaşı"] = 33
df.loc[df["Bina Yaşı"] == "36-40 arası" , "Bina Yaşı"] = 38
df.loc[df["Bina Yaşı"] == "40 ve üzeri" , "Bina Yaşı"] = 43

df.loc[df["Bina Yaşı"] == "Between 6-10" , "Bina Yaşı"] = 8
df.loc[df["Bina Yaşı"] == "Between 11-15" , "Bina Yaşı"] = 13
df.loc[df["Bina Yaşı"] == "Between 16-20" , "Bina Yaşı"] = 18
df.loc[df["Bina Yaşı"] == "Between 21-25" , "Bina Yaşı"] = 23
df.loc[df["Bina Yaşı"] == "Between 26-30" , "Bina Yaşı"] = 28
df.loc[df["Bina Yaşı"] == "Between 31-35" , "Bina Yaşı"] = 33
df.loc[df["Bina Yaşı"] == "Between 36-40" , "Bina Yaşı"] = 38
df.loc[df["Bina Yaşı"] == "40+" , "Bina Yaşı"] = 43

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat Bina Yaşı  \
# 0        100     110                   7           2             3        28
# 1        105     115                   5           2             3         0
# 2        150     170                  15           3             8        13
# 3        100     110                   5           3             2         0
# 4        100     120                   5           3             2         3
# ...      ...     ...                 ...         ...           ...       ...
# 27346     65      85                   4           2             1         4
# 27347    135     145                   6           2             1         8
# 27348    130     141                   6           2             2         0
# 27349     90     110                   4           2             1         8
# 27350    150     160                  15           2            11         8
#
#           Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat         İl  \
# 0                Eşyasız             Boş         Hayır  1350000   İstanbul
# 1                Eşyasız             Boş          Evet   927000   İstanbul
# 2                Eşyasız             Boş          Evet  2300000   İstanbul
# 3      Sadece Beyaz Eşya             Boş          Evet  2800000   İstanbul
# 4      Sadece Beyaz Eşya             Boş          Evet  2623000   İstanbul
# ...                  ...             ...           ...      ...        ...
# 27346  Sadece Beyaz Eşya     Mülk Sahibi          Evet   975000  Zonguldak
# 27347            Eşyasız        Kiracılı          Evet  1050000  Zonguldak
# 27348            Eşyasız             Boş          Evet  1550000  Zonguldak
# 27349            Eşyasız        Kiracılı          Evet   935000  Zonguldak
# 27350            Eşyasız        Kiracılı          Evet  1680000  Zonguldak
#
#                    İlçe                 Mahalle      Oda
# 0              Bağcılar                   Çınar   2 + 1
# 1            Beylikdüzü              Cumhuriyet   2 + 1
# 2            Beylikdüzü                   Barış   3 + 1
# 3            Beylikdüzü                Dereağzı   2 + 1
# 4            Beylikdüzü                Dereağzı   2 + 1
# ...                 ...                     ...      ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak Merkez                 İncivez   3 + 1
# 27348            Ereğli              Sarıkokmaz   3 + 1
# 27349           Çaycuma                     Çay   2 + 1
# 27350            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Mobilya Durumu** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Mobilya Durumu"].unique()
# Out:
# array(['Eşyasız', 'Sadece Beyaz Eşya', nan, 'Eşyalı (Mobilyalı)',
#        'Sadece Mutfak', 'Unfurnished', 'Only Major Appliances',
#        'Kitchen Only', 'Furnished'], dtype=object)

# %%
df.loc[df["Mobilya Durumu"] == "Eşyasız" , "Mobilya Durumu"] = 0
df.loc[df["Mobilya Durumu"] == "Eşyalı (Mobilyalı)" , "Mobilya Durumu"] = 1
df.loc[df["Mobilya Durumu"] == "Sadece Beyaz Eşya" , "Mobilya Durumu"] = 2
df.loc[df["Mobilya Durumu"] == "Sadece Mutfak" , "Mobilya Durumu"] = 3

df.loc[df["Mobilya Durumu"] == "Unfurnished" , "Mobilya Durumu"] = 0
df.loc[df["Mobilya Durumu"] == "Furnished" , "Mobilya Durumu"] = 1
df.loc[df["Mobilya Durumu"] == "Only Major Appliances" , "Mobilya Durumu"] = 2
df.loc[df["Mobilya Durumu"] == "Kitchen Only" , "Mobilya Durumu"] = 3

df["Mobilya Durumu"] = df["Mobilya Durumu"].fillna(4)

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat Bina Yaşı  \
# 0        100     110                   7           2             3        28
# 1        105     115                   5           2             3         0
# 2        150     170                  15           3             8        13
# 3        100     110                   5           3             2         0
# 4        100     120                   5           3             2         3
# ...      ...     ...                 ...         ...           ...       ...
# 27346     65      85                   4           2             1         4
# 27347    135     145                   6           2             1         8
# 27348    130     141                   6           2             2         0
# 27349     90     110                   4           2             1         8
# 27350    150     160                  15           2            11         8
#
#        Mobilya Durumu Kullanım Durumu Krediye Uygun    Fiyat         İl  \
# 0                   0             Boş         Hayır  1350000   İstanbul
# 1                   0             Boş          Evet   927000   İstanbul
# 2                   0             Boş          Evet  2300000   İstanbul
# 3                   2             Boş          Evet  2800000   İstanbul
# 4                   2             Boş          Evet  2623000   İstanbul
# ...               ...             ...           ...      ...        ...
# 27346               2     Mülk Sahibi          Evet   975000  Zonguldak
# 27347               0        Kiracılı          Evet  1050000  Zonguldak
# 27348               0             Boş          Evet  1550000  Zonguldak
# 27349               0        Kiracılı          Evet   935000  Zonguldak
# 27350               0        Kiracılı          Evet  1680000  Zonguldak
#
#                    İlçe                 Mahalle      Oda
# 0              Bağcılar                   Çınar   2 + 1
# 1            Beylikdüzü              Cumhuriyet   2 + 1
# 2            Beylikdüzü                   Barış   3 + 1
# 3            Beylikdüzü                Dereağzı   2 + 1
# 4            Beylikdüzü                Dereağzı   2 + 1
# ...                 ...                     ...      ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak Merkez                 İncivez   3 + 1
# 27348            Ereğli              Sarıkokmaz   3 + 1
# 27349           Çaycuma                     Çay   2 + 1
# 27350            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Kullanım Durumu** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Kullanım Durumu"].unique()
# Out:
# array(['Boş', nan, 'Kiracılı', 'Mülk Sahibi', 'Vacant',
#        'Occupied By Tenant', 'Occupied By Property Owner'], dtype=object)

# %%
df.loc[df["Kullanım Durumu"] == "Boş" , "Kullanım Durumu"] = 0 
df.loc[df["Kullanım Durumu"] == "Mülk Sahibi" , "Kullanım Durumu"] = 1
df.loc[df["Kullanım Durumu"] == "Kiracılı" , "Kullanım Durumu"] = 2

df.loc[df["Kullanım Durumu"] == "Vacant" , "Kullanım Durumu"] = 0 
df.loc[df["Kullanım Durumu"] == "Occupied By Property Owner" , "Kullanım Durumu"] = 1
df.loc[df["Kullanım Durumu"] == "Occupied By Tenant" , "Kullanım Durumu"] = 2

df["Kullanım Durumu"] = df["Kullanım Durumu"].fillna(3)

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat Bina Yaşı  \
# 0        100     110                   7           2             3        28
# 1        105     115                   5           2             3         0
# 2        150     170                  15           3             8        13
# 3        100     110                   5           3             2         0
# 4        100     120                   5           3             2         3
# ...      ...     ...                 ...         ...           ...       ...
# 27346     65      85                   4           2             1         4
# 27347    135     145                   6           2             1         8
# 27348    130     141                   6           2             2         0
# 27349     90     110                   4           2             1         8
# 27350    150     160                  15           2            11         8
#
#        Mobilya Durumu  Kullanım Durumu Krediye Uygun    Fiyat         İl  \
# 0                   0                0         Hayır  1350000   İstanbul
# 1                   0                0          Evet   927000   İstanbul
# 2                   0                0          Evet  2300000   İstanbul
# 3                   2                0          Evet  2800000   İstanbul
# 4                   2                0          Evet  2623000   İstanbul
# ...               ...              ...           ...      ...        ...
# 27346               2                1          Evet   975000  Zonguldak
# 27347               0                2          Evet  1050000  Zonguldak
# 27348               0                0          Evet  1550000  Zonguldak
# 27349               0                2          Evet   935000  Zonguldak
# 27350               0                2          Evet  1680000  Zonguldak
#
#                    İlçe                 Mahalle      Oda
# 0              Bağcılar                   Çınar   2 + 1
# 1            Beylikdüzü              Cumhuriyet   2 + 1
# 2            Beylikdüzü                   Barış   3 + 1
# 3            Beylikdüzü                Dereağzı   2 + 1
# 4            Beylikdüzü                Dereağzı   2 + 1
# ...                 ...                     ...      ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak Merkez                 İncivez   3 + 1
# 27348            Ereğli              Sarıkokmaz   3 + 1
# 27349           Çaycuma                     Çay   2 + 1
# 27350            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Krediye Uygun** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir.

# %%
df["Krediye Uygun"].unique()
# Out:
# array(['Hayır', 'Evet', 'Yes', nan], dtype=object)

# %%
df.loc[df["Krediye Uygun"] == "Evet" , "Krediye Uygun"] = 1
df.loc[df["Krediye Uygun"] == "Yes" , "Krediye Uygun"] = 1
df.loc[df["Krediye Uygun"] == "Hayır" , "Krediye Uygun"] = 0

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat Bina Yaşı  \
# 0        100     110                   7           2             3        28
# 1        105     115                   5           2             3         0
# 2        150     170                  15           3             8        13
# 3        100     110                   5           3             2         0
# 4        100     120                   5           3             2         3
# ...      ...     ...                 ...         ...           ...       ...
# 27346     65      85                   4           2             1         4
# 27347    135     145                   6           2             1         8
# 27348    130     141                   6           2             2         0
# 27349     90     110                   4           2             1         8
# 27350    150     160                  15           2            11         8
#
#        Mobilya Durumu  Kullanım Durumu Krediye Uygun    Fiyat         İl  \
# 0                   0                0             0  1350000   İstanbul
# 1                   0                0             1   927000   İstanbul
# 2                   0                0             1  2300000   İstanbul
# 3                   2                0             1  2800000   İstanbul
# 4                   2                0             1  2623000   İstanbul
# ...               ...              ...           ...      ...        ...
# 27346               2                1             1   975000  Zonguldak
# 27347               0                2             1  1050000  Zonguldak
# 27348               0                0             1  1550000  Zonguldak
# 27349               0                2             1   935000  Zonguldak
# 27350               0                2             1  1680000  Zonguldak
#
#                    İlçe                 Mahalle      Oda
# 0              Bağcılar                   Çınar   2 + 1
# 1            Beylikdüzü              Cumhuriyet   2 + 1
# 2            Beylikdüzü                   Barış   3 + 1
# 3            Beylikdüzü                Dereağzı   2 + 1
# 4            Beylikdüzü                Dereağzı   2 + 1
# ...                 ...                     ...      ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak Merkez                 İncivez   3 + 1
# 27348            Ereğli              Sarıkokmaz   3 + 1
# 27349           Çaycuma                     Çay   2 + 1
# 27350            Ereğli                 Murtaza   3 + 1
#
# [27351 rows x 14 columns]

# %% [markdown]
# **Oda** kolonunun altında bulunan satırlardaki yinelemeyen / benzersiz veriler elde edilip bu kolonun altındaki veriler düzenlenir. Bu kolonun altındaki veriler bize bilgi vermesi için aynı kalmalıdır fakat makine öğrenmesinde kullanıma uygun olabilmesi için **toplam_oda_sayisi** adında yeni bir kolon açılır ve buraya toplam oda sayısı yazılır.

# %%
df["Oda"].unique()
# Out:
# array([' 2 + 1 ', ' 3 + 1 ', ' 1 + 1 ', ' 4 + 1 ', ' 5 + 1 ', ' 5 + 2 ',
#        ' 3 + 2 ', ' 2 + 2 ', ' 4 + 2 ', ' 1 + 0 ', ' 6 + 1 ', ' 6 + 2 ',
#        ' 7 + 2 ', 'Evet', ' 7 + 1 ', ' 8 + 1 ', ' 2 + 0 ',
#        ' 10 ve üzeri ', ' 9 + 2 ', ' 4 + 4 ', ' 6 + 3 ', ' 4 + 3 ',
#        ' 9 + 1 ', ' 9 + 3 ', ' 7 + 3 ', ' 8 + 2 ', 'Hayır', ' 8 + 4 ',
#        ' 8 + 3 ', ' 5 + 3 '], dtype=object)

# %%
df.loc[df["Oda"] == " 3 + 1 " , "toplam_oda_sayisi"] = 4
df.loc[df["Oda"] == " 2 + 1 " , "toplam_oda_sayisi"] = 3
df.loc[df["Oda"] == " 4 + 1 " , "toplam_oda_sayisi"] = 5
df.loc[df["Oda"] == " 1 + 1 " , "toplam_oda_sayisi"] = 2
df.loc[df["Oda"] == " 5 + 1 " , "toplam_oda_sayisi"] = 6
df.loc[df["Oda"] == " 4 + 2 " , "toplam_oda_sayisi"] = 6
df.loc[df["Oda"] == " 5 + 2 " , "toplam_oda_sayisi"] = 7
df.loc[df["Oda"] == " 6 + 1 " , "toplam_oda_sayisi"] = 7
df.loc[df["Oda"] == " 2 + 0 " , "toplam_oda_sayisi"] = 2
df.loc[df["Oda"] == " 3 + 2 " , "toplam_oda_sayisi"] = 5
df.loc[df["Oda"] == " 6 + 2 " , "toplam_oda_sayisi"] = 8
df.loc[df["Oda"] == " 1 + 0 " , "toplam_oda_sayisi"] = 1
df.loc[df["Oda"] == " 2 + 2 " , "toplam_oda_sayisi"] = 4
df.loc[df["Oda"] == " 7 + 1 " , "toplam_oda_sayisi"] = 8
df.loc[df["Oda"] == " 7 + 2 " , "toplam_oda_sayisi"] = 9
df.loc[df["Oda"] == " 4 + 3 " , "toplam_oda_sayisi"] = 7
df.loc[df["Oda"] == " 10 ve üzeri " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 8 + 1 " , "toplam_oda_sayisi"] = 9
df.loc[df["Oda"] == " 4 + 4 " , "toplam_oda_sayisi"] = 8
df.loc[df["Oda"] == " 6 + 3 " , "toplam_oda_sayisi"] = 9
df.loc[df["Oda"] == " 9 + 2 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 8 + 2 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 9 + 3 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 9 + 1 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 8 + 3 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 7 + 3 " , "toplam_oda_sayisi"] = 10
df.loc[df["Oda"] == " 5 + 3 " , "toplam_oda_sayisi"] = 8

# %%
df
# Out:
#       Net m² Brüt m² Binadaki Kat Sayısı Isıtma Tipi Bulunduğu Kat Bina Yaşı  \
# 0        100     110                   7           2             3        28
# 1        105     115                   5           2             3         0
# 2        150     170                  15           3             8        13
# 3        100     110                   5           3             2         0
# 4        100     120                   5           3             2         3
# ...      ...     ...                 ...         ...           ...       ...
# 27346     65      85                   4           2             1         4
# 27347    135     145                   6           2             1         8
# 27348    130     141                   6           2             2         0
# 27349     90     110                   4           2             1         8
# 27350    150     160                  15           2            11         8
#
#        Mobilya Durumu  Kullanım Durumu Krediye Uygun    Fiyat         İl  \
# 0                   0                0             0  1350000   İstanbul
# 1                   0                0             1   927000   İstanbul
# 2                   0                0             1  2300000   İstanbul
# 3                   2                0             1  2800000   İstanbul
# 4                   2                0             1  2623000   İstanbul
# ...               ...              ...           ...      ...        ...
# 27346               2                1             1   975000  Zonguldak
# 27347               0                2             1  1050000  Zonguldak
# 27348               0                0             1  1550000  Zonguldak
# 27349               0                2             1   935000  Zonguldak
# 27350               0                2             1  1680000  Zonguldak
#
#                    İlçe                 Mahalle      Oda  toplam_oda_sayisi
# 0              Bağcılar                   Çınar   2 + 1                 3.0
# 1            Beylikdüzü              Cumhuriyet   2 + 1                 3.0
# 2            Beylikdüzü                   Barış   3 + 1                 4.0
# 3            Beylikdüzü                Dereağzı   2 + 1                 3.0
# 4            Beylikdüzü                Dereağzı   2 + 1                 3.0
# ...                 ...                     ...      ...                ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1                 2.0
# 27347  Zonguldak Merkez                 İncivez   3 + 1                 4.0
# 27348            Ereğli              Sarıkokmaz   3 + 1                 4.0
# 27349           Çaycuma                     Çay   2 + 1                 3.0
# 27350            Ereğli                 Murtaza   3 + 1                 4.0
#
# [27351 rows x 15 columns]

# %% [markdown]
# ### Null Verilerin Silinmesi

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Net m²                 0
# Brüt m²                0
# Binadaki Kat Sayısı    0
# Isıtma Tipi            0
# Bulunduğu Kat          0
# Bina Yaşı              0
# Mobilya Durumu         0
# Kullanım Durumu        0
# Krediye Uygun          0
# Fiyat                  0
# İl                     0
# İlçe                   0
# Mahalle                0
# Oda                    0
# toplam_oda_sayisi      0
# dtype: int64

# %% [markdown]
# ### Sayısal Verilerin Numeric Veriye Dönüştürülmesi

# %%
df[["Net m²","Brüt m²","Binadaki Kat Sayısı","Bulunduğu Kat","Isıtma Tipi","Bina Yaşı","Fiyat","Krediye Uygun","toplam_oda_sayisi"]] = df[["Net m²","Brüt m²","Binadaki Kat Sayısı","Bulunduğu Kat","Isıtma Tipi","Bina Yaşı","Fiyat","Krediye Uygun","toplam_oda_sayisi"]].apply(pd.to_numeric)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23290 entries, 0 to 27350
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Net m²               23290 non-null  int64
#  1   Brüt m²              23290 non-null  int64
#  2   Binadaki Kat Sayısı  23290 non-null  int64
#  3   Isıtma Tipi          23290 non-null  int64
#  4   Bulunduğu Kat        23290 non-null  int64
#  5   Bina Yaşı            23290 non-null  int64
#  6   Mobilya Durumu       23290 non-null  int64
#  7   Kullanım Durumu      23290 non-null  int64
#  8   Krediye Uygun        23290 non-null  int64
#  9   Fiyat                23290 non-null  int64
#  10  İl                   23290 non-null  object
#  11  İlçe                 23290 non-null  object
#  12  Mahalle              23290 non-null  object
#  13  Oda                  23290 non-null  object
#  14  toplam_oda_sayisi    23290 non-null  float64
# dtypes: float64(1), int64(10), object(4)
# memory usage: 2.8+ MB

# %% [markdown]
# >*toplam_oda_sayisi kolonundaki değerler de integer veri tipine dönüştürülür.*

# %%
df.toplam_oda_sayisi = df.toplam_oda_sayisi.astype(int)

# %%
df
# Out:
#        Net m²  Brüt m²  Binadaki Kat Sayısı  Isıtma Tipi  Bulunduğu Kat  \
# 0         100      110                    7            2              3
# 1         105      115                    5            2              3
# 2         150      170                   15            3              8
# 3         100      110                    5            3              2
# 4         100      120                    5            3              2
# ...       ...      ...                  ...          ...            ...
# 27346      65       85                    4            2              1
# 27347     135      145                    6            2              1
# 27348     130      141                    6            2              2
# 27349      90      110                    4            2              1
# 27350     150      160                   15            2             11
#
#        Bina Yaşı  Mobilya Durumu  Kullanım Durumu  Krediye Uygun    Fiyat  \
# 0             28               0                0              0  1350000
# 1              0               0                0              1   927000
# 2             13               0                0              1  2300000
# 3              0               2                0              1  2800000
# 4              3               2                0              1  2623000
# ...          ...             ...              ...            ...      ...
# 27346          4               2                1              1   975000
# 27347          8               0                2              1  1050000
# 27348          0               0                0              1  1550000
# 27349          8               0                2              1   935000
# 27350          8               0                2              1  1680000
#
#               İl              İlçe                 Mahalle      Oda  \
# 0       İstanbul          Bağcılar                   Çınar   2 + 1
# 1       İstanbul        Beylikdüzü              Cumhuriyet   2 + 1
# 2       İstanbul        Beylikdüzü                   Barış   3 + 1
# 3       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# 4       İstanbul        Beylikdüzü                Dereağzı   2 + 1
# ...          ...               ...                     ...      ...
# 27346  Zonguldak           Çaycuma  Filyos Bld. (Hisarönü)   1 + 1
# 27347  Zonguldak  Zonguldak Merkez                 İncivez   3 + 1
# 27348  Zonguldak            Ereğli              Sarıkokmaz   3 + 1
# 27349  Zonguldak           Çaycuma                     Çay   2 + 1
# 27350  Zonguldak            Ereğli                 Murtaza   3 + 1
#
#        toplam_oda_sayisi
# 0                      3
# 1                      3
# 2                      4
# 3                      3
# 4                      3
# ...                  ...
# 27346                  2
# 27347                  4
# 27348                  4
# 27349                  3
# 27350                  4
#
# [23290 rows x 15 columns]

# %% [markdown]
# #### *Kolonların Yeniden İsimlendirilmesi*

# %%
df.columns = ['net_alan', 'brut_alan', 'kat_sayisi', 'isitma', 'bulundugu_kat' ,'bina_yasi', 'esya', 'kullanim_durumu', 'kredi_durumu','fiyat','il','ilce','mahalle','oda_sayisi','toplam_oda_sayisi']

# %%
df
# Out:
#        net_alan  brut_alan  kat_sayisi  isitma  bulundugu_kat  bina_yasi  \
# 0           100        110           7       2              3         28
# 1           105        115           5       2              3          0
# 2           150        170          15       3              8         13
# 3           100        110           5       3              2          0
# 4           100        120           5       3              2          3
# ...         ...        ...         ...     ...            ...        ...
# 27346        65         85           4       2              1          4
# 27347       135        145           6       2              1          8
# 27348       130        141           6       2              2          0
# 27349        90        110           4       2              1          8
# 27350       150        160          15       2             11          8
#
#        esya  kullanim_durumu  kredi_durumu    fiyat         il  \
# 0         0                0             0  1350000   İstanbul
# 1         0                0             1   927000   İstanbul
# 2         0                0             1  2300000   İstanbul
# 3         2                0             1  2800000   İstanbul
# 4         2                0             1  2623000   İstanbul
# ...     ...              ...           ...      ...        ...
# 27346     2                1             1   975000  Zonguldak
# 27347     0                2             1  1050000  Zonguldak
# 27348     0                0             1  1550000  Zonguldak
# 27349     0                2             1   935000  Zonguldak
# 27350     0                2             1  1680000  Zonguldak
#
#                    ilce                 mahalle oda_sayisi  toplam_oda_sayisi
# 0              Bağcılar                   Çınar     2 + 1                   3
# 1            Beylikdüzü              Cumhuriyet     2 + 1                   3
# 2            Beylikdüzü                   Barış     3 + 1                   4
# 3            Beylikdüzü                Dereağzı     2 + 1                   3
# 4            Beylikdüzü                Dereağzı     2 + 1                   3
# ...                 ...                     ...        ...                ...
# 27346           Çaycuma  Filyos Bld. (Hisarönü)     1 + 1                   2
# 27347  Zonguldak Merkez                 İncivez     3 + 1                   4
# 27348            Ereğli              Sarıkokmaz     3 + 1                   4
# 27349           Çaycuma                     Çay     2 + 1                   3
# 27350            Ereğli                 Murtaza     3 + 1                   4
#
# [23290 rows x 15 columns]

# %% [markdown]
# ### Indexlerin yenilenmesi

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# # KONUM

# %% [markdown]
# Konum bilgileri geopy kütüphanesi kullanılarak işleniyor ve koordinat bilgileri elde ediliyor. Koordinat bilgileri verisetine eklenerek makine öğrenmesi algoritmaları bu sayısal veriler üzerinde uygulanacak.

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="MyApp")
from IPython.display import clear_output
from time import sleep

# %%
df["il_ilce"] = df["il"] + " " + df["ilce"]

# %%
unique = df["il_ilce"].unique() #verisetindeki adresler alındı
len(unique)
# Out:
# 411

# %% [markdown]
# Konum bilgileri geopy kütüphanesiyle adres bilgilerini kullanarak elde edildi ve listeye aktarıldı.

# %%
lat = []
lng = []
for i in range(len(unique)):
    location = geolocator.geocode(unique[i])
    lat.append(location.latitude)
    lng.append(location.longitude)
    print(str(i+1) + " adet konum bilgisi listeye aktarıldı.")
    clear_output(wait=True)
    if((i+1)%100==0):   #too many request hatası almamak için 100 işlemde bir duraklama
        sleep(30)
# Out:
# 411 adet konum bilgisi listeye aktarıldı.

# %%
len(lat)
# Out:
# 411

# %% [markdown]
# Konum DataFrame'i Adres, lat ve lng verileri kullanılarak oluşturuldu.

# %%
df_coord = pd.DataFrame()
df_coord["il_ilce"] = pd.Series(unique)
df_coord["lat"] = pd.Series(lat)
df_coord["lng"] = pd.Series(lng)

# %%
df_coord
# Out:
#                         il_ilce        lat        lng
# 0             İstanbul Bağcılar  41.034547  28.856756
# 1           İstanbul Beylikdüzü  41.003754  28.637258
# 2             İstanbul Esenyurt  41.034286  28.680111
# 3         İstanbul Büyükçekmece  41.021654  28.579757
# 4           İstanbul Sancaktepe  40.990520  29.228862
# ..                          ...        ...        ...
# 406            Zonguldak Devrek  41.173557  31.936504
# 407             Zonguldak Kozlu  41.355833  31.742498
# 408  Zonguldak Zonguldak Merkez  41.379246  31.886505
# 409            Zonguldak Alaplı  41.113260  31.472587
# 410           Zonguldak Çaycuma  41.465204  32.113475
#
# [411 rows x 3 columns]

# %% [markdown]
# DataFrame ve konum DataFrame'i adres üzerinde merge edilerek koordinatlar DataFrame'ye aktarıldı.

# %%
df= df.merge(df_coord, how="inner", on="il_ilce")
df.drop(["il_ilce"],axis = 1, inplace= True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23290 entries, 0 to 23289
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   net_alan           23290 non-null  int64
#  1   brut_alan          23290 non-null  int64
#  2   kat_sayisi         23290 non-null  int64
#  3   isitma             23290 non-null  int64
#  4   bulundugu_kat      23290 non-null  int64
#  5   bina_yasi          23290 non-null  int64
#  6   esya               23290 non-null  int64
#  7   kullanim_durumu    23290 non-null  int64
#  8   kredi_durumu       23290 non-null  int64
#  9   fiyat              23290 non-null  int64
#  10  il                 23290 non-null  object
#  11  ilce               23290 non-null  object
#  12  mahalle            23290 non-null  object
#  13  oda_sayisi         23290 non-null  object
#  14  toplam_oda_sayisi  23290 non-null  int64
#  15  lat                23290 non-null  float64
#  16  lng                23290 non-null  float64
# dtypes: float64(2), int64(11), object(4)
# memory usage: 3.2+ MB

# %%
df
# Out:
#        net_alan  brut_alan  kat_sayisi  isitma  bulundugu_kat  bina_yasi  \
# 0           100        110           7       2              3         28
# 1            80         95          15       2             15          3
# 2           110        115           5       1              1         28
# 3            75        135          15       3              3          0
# 4            85        105          10       2              1          8
# ...         ...        ...         ...     ...            ...        ...
# 23285       220        240           5       2              5          0
# 23286       125        135           4       2              2          0
# 23287        95        110           4       2              0          0
# 23288        65         85           4       2              1          4
# 23289        90        110           4       2              1          8
#
#        esya  kullanim_durumu  kredi_durumu    fiyat         il      ilce  \
# 0         0                0             0  1350000   İstanbul  Bağcılar
# 1         0                0             1  2975000   İstanbul  Bağcılar
# 2         0                0             0  1100000   İstanbul  Bağcılar
# 3         0                0             0  2970000   İstanbul  Bağcılar
# 4         2                2             1  2500000   İstanbul  Bağcılar
# ...     ...              ...           ...      ...        ...       ...
# 23285     1                0             1  4170000  Zonguldak   Çaycuma
# 23286     0                0             1  1275000  Zonguldak   Çaycuma
# 23287     0                0             1  1285000  Zonguldak   Çaycuma
# 23288     2                1             1   975000  Zonguldak   Çaycuma
# 23289     0                2             1   935000  Zonguldak   Çaycuma
#
#                       mahalle oda_sayisi  toplam_oda_sayisi        lat  \
# 0                       Çınar     2 + 1                   3  41.034547
# 1                     Göztepe     2 + 1                   3  41.034547
# 2                    100. Yıl     3 + 1                   4  41.034547
# 3                Fevzi Çakmak     2 + 1                   3  41.034547
# 4                     Kirazlı     2 + 1                   3  41.034547
# ...                       ...        ...                ...        ...
# 23285  Filyos Bld. (Hisarönü)     4 + 2                   6  41.465204
# 23286  Filyos Bld. (Hisarönü)     3 + 1                   4  41.465204
# 23287             Pehlivanlar     2 + 1                   3  41.465204
# 23288  Filyos Bld. (Hisarönü)     1 + 1                   2  41.465204
# 23289                     Çay     2 + 1                   3  41.465204
#
#              lng
# 0      28.856756
# 1      28.856756
# 2      28.856756
# 3      28.856756
# 4      28.856756
# ...          ...
# 23285  32.113475
# 23286  32.113475
# 23287  32.113475
# 23288  32.113475
# 23289  32.113475
#
# [23290 rows x 17 columns]

# %%
sns.boxplot(x=df.fiyat)
# Out:
# <AxesSubplot: xlabel='fiyat'>

# %%
df.fiyat.sort_values(ascending=False)
# Out:
# 20459    810000000
# 360       70000000
# 658       67000000
# 466       63500000
# 351       52995000
#            ...
# 3644         24000
# 14861        17000
# 3646         17000
# 5431          6500
# 5459          1350
# Name: fiyat, Length: 23290, dtype: int64

# %%
df.drop(20459, inplace = True)

# %%
mean = df.fiyat.mean()

# %%
sns.kdeplot(data=df.fiyat)
# Out:
# <AxesSubplot: xlabel='fiyat', ylabel='Density'>

# %%
sns.histplot(data=df[df.fiyat>mean*10].fiyat, bins=70)
plt.grid()

# %% [markdown]
# 35.000.000 fiyata kadar yoğunluk görülmekte

# %%
sns.boxplot(x=df[(df.fiyat<35000000)].fiyat) 
plt.grid()

# %% [markdown]
# 35 milyona kadar olan aralıkta yoğunluk 15 milyona kadar gözlemlenmekte.

# %%
sns.histplot(data=df[df.fiyat<mean/4].fiyat, bins=40)
plt.grid()

# %%
sns.histplot(data=df[(df.fiyat<500000) & (df.fiyat>200000)].fiyat, bins=40)
plt.grid()

# %%
sns.histplot(data=df[(df.fiyat<370000) & (df.fiyat>330000)].fiyat, bins=20)
plt.grid()

# %% [markdown]
# Düşük fiyatlar incelendiğinde 350.000 bandında yoğunluk tespit edildi. Alt limit 350.000 olarak belirlendi.

# %%
df = df[(df.fiyat>295000) & (df.fiyat < 15500000)]

# %%
df = df.reset_index(drop=True)

# %%
df
# Out:
#        net_alan  brut_alan  kat_sayisi  isitma  bulundugu_kat  bina_yasi  \
# 0           100        110           7       2              3         28
# 1            80         95          15       2             15          3
# 2           110        115           5       1              1         28
# 3            75        135          15       3              3          0
# 4            85        105          10       2              1          8
# ...         ...        ...         ...     ...            ...        ...
# 23029       220        240           5       2              5          0
# 23030       125        135           4       2              2          0
# 23031        95        110           4       2              0          0
# 23032        65         85           4       2              1          4
# 23033        90        110           4       2              1          8
#
#        esya  kullanim_durumu  kredi_durumu    fiyat         il      ilce  \
# 0         0                0             0  1350000   İstanbul  Bağcılar
# 1         0                0             1  2975000   İstanbul  Bağcılar
# 2         0                0             0  1100000   İstanbul  Bağcılar
# 3         0                0             0  2970000   İstanbul  Bağcılar
# 4         2                2             1  2500000   İstanbul  Bağcılar
# ...     ...              ...           ...      ...        ...       ...
# 23029     1                0             1  4170000  Zonguldak   Çaycuma
# 23030     0                0             1  1275000  Zonguldak   Çaycuma
# 23031     0                0             1  1285000  Zonguldak   Çaycuma
# 23032     2                1             1   975000  Zonguldak   Çaycuma
# 23033     0                2             1   935000  Zonguldak   Çaycuma
#
#                       mahalle oda_sayisi  toplam_oda_sayisi        lat  \
# 0                       Çınar     2 + 1                   3  41.034547
# 1                     Göztepe     2 + 1                   3  41.034547
# 2                    100. Yıl     3 + 1                   4  41.034547
# 3                Fevzi Çakmak     2 + 1                   3  41.034547
# 4                     Kirazlı     2 + 1                   3  41.034547
# ...                       ...        ...                ...        ...
# 23029  Filyos Bld. (Hisarönü)     4 + 2                   6  41.465204
# 23030  Filyos Bld. (Hisarönü)     3 + 1                   4  41.465204
# 23031             Pehlivanlar     2 + 1                   3  41.465204
# 23032  Filyos Bld. (Hisarönü)     1 + 1                   2  41.465204
# 23033                     Çay     2 + 1                   3  41.465204
#
#              lng
# 0      28.856756
# 1      28.856756
# 2      28.856756
# 3      28.856756
# 4      28.856756
# ...          ...
# 23029  32.113475
# 23030  32.113475
# 23031  32.113475
# 23032  32.113475
# 23033  32.113475
#
# [23034 rows x 17 columns]

# %%
df.to_csv("../data/zingat_preprocessed.csv")
